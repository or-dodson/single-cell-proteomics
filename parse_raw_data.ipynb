# %%
# Get all file paths

list_of_all_filenames = [ 'bulk_rep1','bulk_rep2','bulk_rep3',
                        '2ng_rep1','2ng_rep2','2ng_rep3','2ng_rep4','2ng_rep5','2ng_rep6',
                        '0.2ng_rep1','0.2ng_rep2','0.2ng_rep3','0.2ng_rep4','0.2ng_rep5','0.2ng_rep6',
                        'sc_rep1','sc_rep2','sc_rep3','sc_rep4','sc_rep5']


psm_files = {}
#bulk
path_bulk = "data/psm/Project_PXD011163/"
psm_files["bulk_rep1"] = path_bulk + "OR11_20160122_PG_HeLa_CVB3_CT_A-calib_PSMs.psmtsv.gz"
psm_files["bulk_rep2"] = path_bulk + "OR11_20160122_PG_HeLa_CVB3_CT_B-calib_PSMs.psmtsv.gz"
psm_files["bulk_rep3"] = path_bulk + "OR11_20160122_PG_HeLa_CVB3_CT_C-calib_PSMs.psmtsv.gz"

#2ng
path_2ng = "data/psm/2ng/"
psm_files["2ng_rep1"] = path_2ng + "Ex_Auto_J3_30umTB_2ngQC_60m_1-calib_PSMs.psmtsv.gz"
psm_files["2ng_rep2"] = path_2ng + "Ex_Auto_J3_30umTB_2ngQC_60m_2-calib_PSMs.psmtsv.gz"
psm_files["2ng_rep3"] = path_2ng + "Ex_Auto_K13_30umTA_2ngQC_60m_1-calib_PSMs.psmtsv.gz"
psm_files["2ng_rep4"] = path_2ng + "Ex_Auto_K13_30umTA_2ngQC_60m_2-calib_PSMs.psmtsv.gz"
psm_files["2ng_rep5"] = path_2ng + "Ex_Auto_W17_30umTB_2ngQC_60m_1-calib_PSMs.psmtsv.gz"
psm_files["2ng_rep6"] = path_2ng + "Ex_Auto_W17_30umTB_2ngQC_60m_2-calib_PSMs.psmtsv.gz"

#.2ng
path_02ng = "data/psm/02ng/"
psm_files["0.2ng_rep1"] = path_02ng + "Ex_Auto_J3_30umTB_02ngQC_60m_1-calib_PSMs.psmtsv.gz"
psm_files["0.2ng_rep2"] = path_02ng + "Ex_Auto_J3_30umTB_02ngQC_60m_2-calib_PSMs.psmtsv.gz"
psm_files["0.2ng_rep3"] = path_02ng + "Ex_Auto_K13_30umTA_02ngQC_60m_1-calib_PSMs.psmtsv.gz"
psm_files["0.2ng_rep4"] = path_02ng + "Ex_Auto_K13_30umTA_02ngQC_60m_2-calib_PSMs.psmtsv.gz"
psm_files["0.2ng_rep5"] = path_02ng + "Ex_Auto_W17_30umTA_02ngQC_60m_3-calib_PSMs.psmtsv.gz"
psm_files["0.2ng_rep6"] = path_02ng + "Ex_Auto_W17_30umTA_02ngQC_60m_4-calib_PSMs.psmtsv.gz"
#
#True SC
path_sc = "data/psm/true_SC/"
psm_files["sc_rep1"] = path_sc + "D19_15um30cm_SC1-calib_PSMs.psmtsv.gz"
psm_files["sc_rep2"] = path_sc + "D19_15um30cm_SC2-calib_PSMs.psmtsv.gz"
psm_files["sc_rep3"] = path_sc + "D19_15um30cm_SC3-calib_PSMs.psmtsv.gz"
psm_files["sc_rep4"] = path_sc + "D19_15um30cm_SC4-calib_PSMs.psmtsv.gz"
psm_files["sc_rep5"] = path_sc + "D19_15um30cm_SC5-calib_PSMs.psmtsv.gz"

mzml_files = {}
#bulk
path_mzml = "data/mzMLs/"
mzml_files["bulk_rep1"] = path_mzml + "OR11_20160122_PG_HeLa_CVB3_CT_A.mzML"
mzml_files["bulk_rep2"] = path_mzml + "OR11_20160122_PG_HeLa_CVB3_CT_B.mzML"
mzml_files["bulk_rep3"] = path_mzml + "OR11_20160122_PG_HeLa_CVB3_CT_C.mzML"

#2ng
mzml_files["2ng_rep1"] = path_mzml + "Ex_Auto_J3_30umTB_2ngQC_60m_1.mzML"
mzml_files["2ng_rep2"] = path_mzml + "Ex_Auto_J3_30umTB_2ngQC_60m_2.mzML"
mzml_files["2ng_rep3"] = path_mzml + "Ex_Auto_K13_30umTA_2ngQC_60m_1.mzML"
mzml_files["2ng_rep4"] = path_mzml + "Ex_Auto_K13_30umTA_2ngQC_60m_2.mzML"
mzml_files["2ng_rep5"] = path_mzml + "Ex_Auto_W17_30umTB_2ngQC_60m_1.mzML"
mzml_files["2ng_rep6"] = path_mzml + "Ex_Auto_W17_30umTB_2ngQC_60m_2.mzML"

mzml_files["0.2ng_rep1"] = path_mzml + "Ex_Auto_J3_30umTB_02ngQC_60m_1.mzML"
mzml_files["0.2ng_rep2"] = path_mzml + "Ex_Auto_J3_30umTB_02ngQC_60m_2.mzML"
mzml_files["0.2ng_rep3"] = path_mzml + "Ex_Auto_K13_30umTA_02ngQC_60m_1.mzML"
mzml_files["0.2ng_rep4"] = path_mzml + "Ex_Auto_K13_30umTA_02ngQC_60m_2.mzML"
mzml_files["0.2ng_rep5"] = path_mzml + "Ex_Auto_W17_30umTA_02ngQC_60m_3.mzML"
mzml_files["0.2ng_rep6"] = path_mzml + "Ex_Auto_W17_30umTA_02ngQC_60m_4.mzML"

mzml_files["sc_rep1"] = path_mzml + "D19_15um30cm_SC1.mzML"
mzml_files["sc_rep2"] = path_mzml + "D19_15um30cm_SC2.mzML"
mzml_files["sc_rep3"] = path_mzml + "D19_15um30cm_SC3.mzML"
mzml_files["sc_rep4"] = path_mzml + "D19_15um30cm_SC4.mzML"
mzml_files["sc_rep5"] = path_mzml + "D19_15um30cm_SC5.mzML"


list_of_sc_filenames = ['sc_rep1','sc_rep2','sc_rep3','sc_rep4','sc_rep5']
list_of_2ng_filenames = ['2ng_rep1', '2ng_rep2', '2ng_rep3', '2ng_rep4', '2ng_rep5', '2ng_rep6']
list_of_02ng_filenames = ['0.2ng_rep1','0.2ng_rep2','0.2ng_rep3','0.2ng_rep4','0.2ng_rep5','0.2ng_rep6']
list_of_filenames_to_parse = ['2ng_rep1','2ng_rep2','2ng_rep3','2ng_rep4','2ng_rep5','2ng_rep6',
                        '0.2ng_rep1','0.2ng_rep2','0.2ng_rep3','0.2ng_rep4','0.2ng_rep5','0.2ng_rep6',
                        'sc_rep1','sc_rep2','sc_rep3','sc_rep4','sc_rep5']

# %%
from combine_psm_mzml import *

for file_name in list_of_all_filenames:
    
    # PSM
    psm_path = psm_files.get(file_name)
    # MZML
    mzml_path = mzml_files.get(file_name)

    # This funciton currently cleans and does that last bit of saving as a new file
    df = clean_and_combine(psm_path, mzml_path)
    
    # Save changes as new file
    write_file_path = "data/parsed_psm/" + file_name + ".tsv"
    df.to_csv(write_file_path, sep="\t")
